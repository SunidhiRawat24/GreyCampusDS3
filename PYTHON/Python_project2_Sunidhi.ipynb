# %%
import pandas as pd 
import os, glob
df = pd.read_excel("C:/Users/sunid/Downloads/imus.xlsx")
df
# Out:
#          category                manufacturer      part_number     sku  \
# 0            1539  MS-OPEN VALUE SUBSCRIPTION        021-09108  BA0011
# 1            1539  MS-OPEN VALUE SUBSCRIPTION        059-07014  BA0025
# 2            1539  MS-OPEN VALUE SUBSCRIPTION        065-06444  BA0039
# 3            1539  MS-OPEN VALUE SUBSCRIPTION        076-04355  BA0067
# 4            1582  MS-OPEN VALUE SUBSCRIPTION        077-05318  BA0080
# ...           ...                         ...              ...     ...
# 1048570      1241          IOSAFE DIRECT SHIP  75200-3838-1500  6QP586
# 1048571      1241          IOSAFE DIRECT SHIP  75200-3838-1500  6QP586
# 1048572      1241          IOSAFE DIRECT SHIP  75200-3840-1500  6QP587
# 1048573      1241          IOSAFE DIRECT SHIP  75200-3840-1500  6QP587
# 1048574      1241          IOSAFE DIRECT SHIP  75200-3840-1500  6QP587
#
#         alt_sku                                        description    status  \
# ...

# %%
df['total_price']=df['qty']*df['price']
df.sort_values("total_price", ascending=False)
# Out:
#          category                      manufacturer        part_number  \
# 625985       1221       DELL CSG SERVICE WARRANTIES           818-6447
# 625984       1221               DELL ESG WARRANTIES           818-6446
# 399288       1251       IM CHOICE ADVANTAGE - GOVED            FEDADV1
# 625983       1221               DELL ESG WARRANTIES           818-6445
# 625982       1221       DELL CSG SERVICE WARRANTIES           818-6444
# ...           ...                               ...                ...
# 398287       1221            CISCO - SV DIRECT SHIP  CON-ECMU-C1F1C382
# 398288       1221  CISCO - TAKEOVER ENTERPRISE SKUS  CON-ECMU-C1F1C382
# 398289       1221        CISCO - CISCO CCW SERVICES  CON-ECMU-C1F1C382
# 398290       1221        CISCO - CISCO CCW SERVICES  CON-ECMU-C1F1C382
# 1048574      1241                IOSAFE DIRECT SHIP    75200-3840-1500
#
#             sku alt_sku                                        description  \
# ...

# %%
#Which are the most profitable products?
profit_prod = df.sort_values('price', ascending = False)
profit_prod
# Out:
#          category                manufacturer         part_number     sku  \
# 1046052      1231                      ALTNET   ALT-TPM-240000000  6QN385
# 1046051      1231                      ALTNET    ALT-TPM-80000000  6QN384
# 973610       1241        JUNIPER ROW SERVICES  SV5-SWA-JCE-1KGBPS  6JB451
# 973606       1241        JUNIPER ROW SERVICES  SV3-SWA-JCE-1KGBPS  6JB398
# 997704       1241  JUNIPER ENTERPRISE ROUTING  QSFP-100G-LR4-1000  6KG376
# ...           ...                         ...                 ...     ...
# 720909       9920        4E PROJECT/ACME MADE         AM10511-SLV  4R2115
# 720908       9920        4E PROJECT/ACME MADE         AM10631-SLV  4R2114
# 720907       9920        4E PROJECT/ACME MADE         AM10621-SLV  4R2113
# 720906       9920        4E PROJECT/ACME MADE         AM10611-SLV  4R2112
# 720895       9920        4E PROJECT/ACME MADE             AM36796  4R2101
#
#         alt_sku                                        description    status  \
# ...

# %%
#Which is the product where you have seen decrease in the price?

# %%
#Which is the top category by price and quantity?
top_values = df.sort_values(["price","qty"], ascending = False)
top_values
# Out:
#          category                manufacturer         part_number     sku  \
# 1046052      1231                      ALTNET   ALT-TPM-240000000  6QN385
# 1046051      1231                      ALTNET    ALT-TPM-80000000  6QN384
# 973610       1241        JUNIPER ROW SERVICES  SV5-SWA-JCE-1KGBPS  6JB451
# 973606       1241        JUNIPER ROW SERVICES  SV3-SWA-JCE-1KGBPS  6JB398
# 997704       1241  JUNIPER ENTERPRISE ROUTING  QSFP-100G-LR4-1000  6KG376
# ...           ...                         ...                 ...     ...
# 720916       9920        4E PROJECT/ACME MADE          AM20111-HT  4R2123
# 720918       9920        4E PROJECT/ACME MADE          AM20311-HT  4R2125
# 720919       9920        4E PROJECT/ACME MADE          AM20411-HT  4R2126
# 743072       1211   ROYAL SOVEREIGN LAMINATOR       INSTAPP1YRWMA  5CV696
# 774119       1221   ROYAL SOVEREIGN LAMINATOR        W3X2000-4999  5GD479
#
#         alt_sku                                        description    status  \
# ...

# %%
#Which products are aging?
dates  = pd.date_range (start = "2020-08-17", period =2 , freq= "Y")
dates
aging_values = df.sort_values("qty", ascending = False)
aging_values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-7fa903d00362> in <module>
#       1 #Which products are aging?
# ----> 2 dates  = pd.date_range (start = "2020-08-17", period =2 , freq= "Y")
#       3 dates
#       4 aging_values = df.sort_values("qty", ascending = False)
#       5 aging_values
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in date_range(start, end, periods, freq, tz, normalize, name, closed, **kwargs)
#     997         freq = "D"
#     998
# --> 999     dtarr = DatetimeArray._generate_range(
#    1000         start=start,
#    1001         end=end,
#
# TypeError: _generate_range() got an unexpected keyword argument 'period'

# %%
#FOR DATA NOT IN STOCK 

#Which are the top Manufacturers with price, quantity
top_manu = df[df.status == 'No Stock'].sort_values(['price'], ascending=(False) )
top_manu
top_manu1 = top_manu.sort_values(['price','qty'],ascending= False)
top_manu1[['manufacturer','qty','price']].drop_duplicates().head(10)
# Out:
#                         manufacturer  qty        price
# 1046052                       ALTNET    0  84974533.10
# 1046051                       ALTNET    0  28324844.37
# 973610          JUNIPER ROW SERVICES    0  10449000.00
# 973606          JUNIPER ROW SERVICES    0   6966000.00
# 997704    JUNIPER ENTERPRISE ROUTING    0   5600000.00
# 388644        CISCO - CCW MULTI YEAR    0   4700430.00
# 388652        CISCO - CCW MULTI YEAR    0   4476600.00
# 971703   HPE - ENTERPRISE NETWORKING    0   4173518.27
# 388568        CISCO - CCW MULTI YEAR    0   3837086.35
# 388645        CISCO - CCW MULTI YEAR    0   3820950.00

# %%
#Which are the most profitable products?
profit_pod2 = top_manu1.drop_duplicates()
profit_prod2 = df.sort_values('price', ascending = False).head(10)
profit_prod2
# Out:
#          category                 manufacturer         part_number     sku  \
# 1046052      1231                       ALTNET   ALT-TPM-240000000  6QN385
# 1046051      1231                       ALTNET    ALT-TPM-80000000  6QN384
# 973610       1241         JUNIPER ROW SERVICES  SV5-SWA-JCE-1KGBPS  6JB451
# 973606       1241         JUNIPER ROW SERVICES  SV3-SWA-JCE-1KGBPS  6JB398
# 997704       1241   JUNIPER ENTERPRISE ROUTING  QSFP-100G-LR4-1000  6KG376
# 388644       1221       CISCO - CCW MULTI YEAR  CON-3ECMU-LTCLX3UL  ZA6698
# 388652       1221       CISCO - CCW MULTI YEAR  CON-3ECMU-LTCAEEX3  ZA6702
# 971703       1577  HPE - ENTERPRISE NETWORKING            R1Z91AAE  6HT207
# 388568       1221       CISCO - CCW MULTI YEAR  CON-3ECMU-LPHOME6S  ZA6660
# 388645       1221       CISCO - CCW MULTI YEAR  CON-3ECMU-LTCLX3UL  ZA6698
#
#         alt_sku                                        description    status  \
# ...

# %%
#Which is the top category by price and quantity?
top_values2 = top_manu1.drop_duplicates()
top_values2 = df.sort_values(["price","qty"], ascending = False).head(10)
top_values2
# Out:
#          category                 manufacturer         part_number     sku  \
# 1046052      1231                       ALTNET   ALT-TPM-240000000  6QN385
# 1046051      1231                       ALTNET    ALT-TPM-80000000  6QN384
# 973610       1241         JUNIPER ROW SERVICES  SV5-SWA-JCE-1KGBPS  6JB451
# 973606       1241         JUNIPER ROW SERVICES  SV3-SWA-JCE-1KGBPS  6JB398
# 997704       1241   JUNIPER ENTERPRISE ROUTING  QSFP-100G-LR4-1000  6KG376
# 388644       1221       CISCO - CCW MULTI YEAR  CON-3ECMU-LTCLX3UL  ZA6698
# 388652       1221       CISCO - CCW MULTI YEAR  CON-3ECMU-LTCAEEX3  ZA6702
# 971703       1577  HPE - ENTERPRISE NETWORKING            R1Z91AAE  6HT207
# 388568       1221       CISCO - CCW MULTI YEAR  CON-3ECMU-LPHOME6S  ZA6660
# 388645       1221       CISCO - CCW MULTI YEAR  CON-3ECMU-LTCLX3UL  ZA6698
#
#         alt_sku                                        description    status  \
# ...
