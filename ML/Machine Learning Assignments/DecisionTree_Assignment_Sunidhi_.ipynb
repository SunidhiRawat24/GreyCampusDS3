# %%
#importing the required libraries 
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
#reading the csv file 
data = pd.read_csv("C:/Users/sunid/Downloads/IceCreamData.csv")
data
# Out:
#      Temperature     Revenue
# 0      24.566884  534.799028
# 1      26.005191  625.190122
# 2      27.790554  660.632289
# 3      20.595335  487.706960
# 4      11.503498  316.240194
# ..           ...         ...
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388
#
# [500 rows x 2 columns]

# %%
data.head(10)
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194
# 5    14.352514  367.940744
# 6    13.707780  308.894518
# 7    30.833985  696.716640
# 8     0.976870   55.390338
# 9    31.669465  737.800824

# %%
#
data.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.232225   521.570777
# std       8.096388   175.404751
# min       0.000000    10.000000
# 25%      17.122258   405.558681
# 50%      22.392791   529.368565
# 75%      27.740674   642.257922
# max      45.000000  1000.000000

# %%
Temp = data["Temperature"].values
Temp
# Out:
# array([24.56688442, 26.00519115, 27.79055388, 20.59533505, 11.50349764,
#        14.35251388, 13.70777988, 30.83398474,  0.97686999, 31.66946458,
#        11.45525338,  3.66466958, 18.81182403, 13.62450892, 39.53990899,
#        18.48314099, 25.93537514, 42.51528041, 29.58948056, 21.77594799,
#        25.45783637, 15.21456942, 22.61931574, 16.25872074, 23.88172478,
#        18.97830025, 15.6614643 , 29.18504465, 19.02461092, 35.12015142,
#        24.18393726, 15.23119012,  8.79095281, 18.23322784, 35.62892497,
#        37.05754246, 22.28455032, 17.51707397, 31.7379196 , 17.04973761,
#        23.0034888 ,  8.75555394, 18.77535808, 14.10966102, 18.63391286,
#        15.67648661, 20.94791347, 30.6353071 , 20.47359412, 31.22898848,
#         6.39383463, 27.18581031, 28.63373276, 27.99922248, 10.32638937,
#        27.31281141, 33.23567229, 36.56911506, 12.46293731, 14.37969698,
#        16.30255473, 11.56964367, 33.55141872,  3.98652317, 20.51163741,
# ...

# %%
Rev = data["Revenue"].values
Rev
# Out:
# array([ 534.7990284 ,  625.1901215 ,  660.6322888 ,  487.7069603 ,
#         316.2401944 ,  367.9407438 ,  308.8945179 ,  696.7166402 ,
#          55.39033824,  737.8008241 ,  325.9684084 ,   71.16015301,
#         467.4467066 ,  289.5409341 ,  905.4776043 ,  469.9090332 ,
#         648.2099977 ,  921.508275  ,  649.5611747 ,  534.6228653 ,
#         612.1539491 ,  353.3256334 ,  524.2361154 ,  374.231135  ,
#         523.1245467 ,  473.6043349 ,  402.4553204 ,  679.3177906 ,
#         517.5340283 ,  809.6720534 ,  528.3804165 ,  356.0980075 ,
#         237.7639106 ,  418.1372788 ,  809.4634112 ,  870.7659159 ,
#         550.2785159 ,  405.6614459 ,  740.9356848 ,  501.7329901 ,
#         539.6880057 ,  242.2362083 ,  421.621505  ,  358.0028493 ,
#         467.631063  ,  396.9356482 ,  500.9250645 ,  651.8615363 ,
#         451.4507843 ,  697.8339862 ,  190.7109408 ,  621.1897304 ,
#         666.1368355 ,  628.4532107 ,  219.3039932 ,  623.5988607 ,
# ...

# %%
from sklearn.model_selection import train_test_split
Temp_train,Temp_test,Rev_train,Rev_test = train_test_split(Temp,Rev , test_size = 0.3, random_state = 1)

# %%
from sklearn.tree import DecisionTreeRegressor
DTR = DecisionTreeRegressor(max_depth = 3)
DTR.fit(Temp_train.reshape(-1,1) , Rev_train.reshape(-1,1))
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
#checking score of training as well as testing
print(DTR.score(Temp_train.reshape(-1,1), Rev_train.reshape(-1,1)))
print(DTR.score(Temp_test.reshape(-1,1),Rev_test.reshape(-1,1)))
# Out:
# 0.9560761115465451
# 0.943903439528122

# %%
pred = DTR.predict(Temp_test.reshape(-1,1))

# %%
#creating data frame 
Df = pd.DataFrame({"Actual Temprature":Temp_test.reshape(-1),"Actual Revenue":Rev_test.reshape(-1),"Predicted Revvenue" : pred.reshape(-1)})
Df
# Out:
#      Actual Temprature  Actual Revenue  Predicted Revvenue
# 0            30.028207      714.560056          643.614998
# 1            25.551200      579.307388          560.113379
# 2            30.635307      651.861536          643.614998
# 3            11.694538      284.772789          296.362026
# 4            18.508360      432.819795          408.013138
# ..                 ...             ...                 ...
# 145          29.241752      678.751388          643.614998
# 146          31.579989      715.124695          754.186986
# 147           9.018860      212.591740          296.362026
# 148          28.262831      655.433979          643.614998
# 149          16.258721      374.231135          408.013138
#
# [150 rows x 3 columns]

# %%
plt.scatter(Temp_test , Rev_test , color  = "Red")
plt.scatter(Temp_test, pred , color = "Green")
plt.show #data visiualisation
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
